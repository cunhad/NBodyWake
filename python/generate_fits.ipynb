# %%
matplotlib inline
import numpy as np
import healpy as hp
# Out:
# /home/asus/Programs/anaconda/Programs/anaconda/lib/python2.7/site-packages/pyfits/__init__.py:22: PyFITSDeprecationWarning: PyFITS is deprecated, please use astropy.io.fits
#   PyFITSDeprecationWarning)  # noqa

# %%
dataname="/home/asus/Dropbox/Disrael/Doutorado/Research/NBodyWake/production/Analysis/wake_detection/box_statistics/tests/_3_out_filtered_1dproj_angle_z10_anglparts8_NSIDE1024_full.bin"
#dataname="/home/asus/Dropbox/Disrael/Doutorado/Research/NBodyWake/production/Analysis/wake_detection/box_statistics/tests/_4_out_filtered_1dproj_angle_z10_anglparts4_NSIDE64_full.bin"

# %%
data = np.fromfile(dataname, dtype=np.float32)
data
# Out:
# array([  3.55359050e-03,   5.19258669e-04,   6.84358406e+00, ...,
#          3.14575434e-03,   5.36933600e-04,   5.85873985e+00], dtype=float32)

# %%
#hp.mollview(data, title="Mollview image RING")
len(data)
# Out:
# 37748736

# %%
s=data[0::3]

# %%
len(s)
# Out:
# 12582912

# %%
hp.mollview(s, title="Mollview image RING")

# %%
from astropy.io import fits

# %%
#from healpy import fitsfunc
# Out:
# /home/asus/Programs/anaconda/Programs/anaconda/lib/python2.7/site-packages/pyfits/__init__.py:22: PyFITSDeprecationWarning: PyFITS is deprecated, please use astropy.io.fits
#   PyFITSDeprecationWarning)  # noqa

# %%
#hp.fitsfunc.mwrfits("test.fits",s)

# %%
#s.write('table1.fits', format='fits')
from astropy.table import Table
T=Table([s],names=('a'))

# %%
T.write('table2.fits', format='fits')
