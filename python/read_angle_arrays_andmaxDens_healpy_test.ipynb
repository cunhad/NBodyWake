# %%
matplotlib inline

# %%
import numpy as np
import healpy as hp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-648e7fce0e53> in <module>()
#       1 import numpy as np
# ----> 2 import healpy as hp
#
# ImportError: No module named healpy

# %%
angles=np.loadtxt('angles8.txt', delimiter=' ');
#angles

# %%
NPix=angles.shape[1]
NSIDE = np.int(np.sqrt(NPix/12))

# %%
NSIDE,NPix
# Out:
# (8, 768)

# %%
max_density=np.loadtxt('random_test8.txt', delimiter=' ');
#max_density

# %%
hp.mollview(max_density, title="Mollview image RING")

# %%
hp.mollview(max_density, title="Mollview image RING",png='file.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-d21578b8a743> in <module>()
# ----> 1 hp.mollview(max_density, title="Mollview image RING",png='file.png')
#
# TypeError: mollview() got an unexpected keyword argument 'png'

# %%
hp.mollview(max_density, coord=['G','E'], title='Histogram equalized Ecliptic', unit='mK', norm='hist', min=-1,max=1, xsize=2000)
hp.graticule()
# Out:
# /home/asus/Programs/miniconda2/lib/python2.7/site-packages/healpy/projaxes.py:808: MaskedArrayFutureWarning: setting an item on a masked array which has a shared mask will not copy the mask and also change the original mask array in the future.
# Check the NumPy 1.11 release notes for more information.
#   result[np.isinf(val.data)] = -np.inf
# 0.0 180.0 -180.0 180.0
# The interval between parallels is 30 deg -0.00'.
# The interval between meridians is 30 deg -0.00'.

# %%
hp.zoomtool.mollzoom(max_density, title="Mollview image RING")
