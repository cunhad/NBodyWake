# %%
matplotlib inline

# %%
import numpy as np
import healpy as hp
from pylab import *
import matplotlib.pyplot as plt
import re
import glob
import os

# %%
#specification on what we are computing

comp='max_1dproj'
comp2='sigma'

# %%
#from irulan 1 node 

data_path="/home/asus/Dropbox/extras/storage/guillimin/64Mpc_1024c_512p_zi63_wakeGmu8t10m7zi31m/sample0001/data/2lf_1rf_0-0-0pv/stat/box_statistics/halos/all_nodes_1dproj_analysis/dc_wrt_dm_avr/"+comp+"/*64.txt"

# %%
#out path

out_path="/home/asus/Dropbox/extras/storage/guillimin/64Mpc_1024c_512p_zi63_wakeGmu8t10m7zi31m/sample0001/plot/2lf_1rf_0-0-0pv/stat/box_statistics/halos/all_nodes_1dproj_analysis/dc_wrt_dm_avr/"+comp+"/"

# %%
min_rang=0
max_rang=1
max_rang2=10

# %%
angles=np.loadtxt('angles64.txt', delimiter=' ');
#angles

# %%
NPix=angles.shape[1]
NSIDE = np.int(np.sqrt(NPix/12))

# %%
NSIDE,NPix
# Out:
# (64, 49152)

# %%
files_list = sorted(glob.glob(data_path))
files_list
# Out:
# []

# %%
for i in range(0,len(files_list)):
    redshift = re.split("_",re.split("/", files_list[i])[-1])[-2][1:]
    print redshift
    
    directory_out=out_path+'mollweide/'+'001_'+'lin_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'001_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang)
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'001_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2)
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'mollweide/'+'001_'+'hist_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='hist')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'001_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,norm='hist')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'001_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,norm='hist')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
#     directory_out=out_path+'mollweide/'+'001_'+'log_'+'minmaxrang/'
#     if not os.path.exists(directory_out):
#         os.makedirs(directory_out)
#     max_density=np.loadtxt(files_list[i], delimiter=' ');
#     hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='log')
#     plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
#     directory_out=out_path+'mollweide/'+'001_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
#     if not os.path.exists(directory_out):
#         os.makedirs(directory_out)
#     max_density=np.loadtxt(files_list[i], delimiter=' ');
#     hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang,norm='log')
#     plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
#     directory_out=out_path+'mollweide/'+'001_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
#     if not os.path.exists(directory_out):
#         os.makedirs(directory_out)
#     max_density=np.loadtxt(files_list[i], delimiter=' ');
#     hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang2,norm='log')
#     plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    
    directory_out=out_path+'mollweide/'+'010_'+'lin_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'010_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'010_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'mollweide/'+'010_'+'hist_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='hist',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'010_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,norm='hist',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'010_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,norm='hist',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
#     directory_out=out_path+'mollweide/'+'010_'+'log_'+'minmaxrang/'
#     if not os.path.exists(directory_out):
#         os.makedirs(directory_out)
#     max_density=np.loadtxt(files_list[i], delimiter=' ');
#     hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='log',rot=(0,0,90))
#     plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
#     directory_out=out_path+'mollweide/'+'010_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
#     if not os.path.exists(directory_out):
#         os.makedirs(directory_out)
#     max_density=np.loadtxt(files_list[i], delimiter=' ');
#     hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang,norm='log',rot=(0,0,90))
#     plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
#     directory_out=out_path+'mollweide/'+'010_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
#     if not os.path.exists(directory_out):
#         os.makedirs(directory_out)
#     max_density=np.loadtxt(files_list[i], delimiter=' ');
#     hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang2,norm='log',rot=(0,0,90))
#     plt.savefig(directory_out+'1dproj_max_z'+redshift+'.jpg')
    
    
    
    directory_out=out_path+'mollweide/'+'100_'+'lin_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'100_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'100_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'mollweide/'+'100_'+'hist_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='hist',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'100_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,norm='hist',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'100_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,norm='hist',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
#     directory_out=out_path+'mollweide/'+'100_'+'log_'+'minmaxrang/'
#     if not os.path.exists(directory_out):
#         os.makedirs(directory_out)
#     max_density=np.loadtxt(files_list[i], delimiter=' ');
#     hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='log',rot=(0,90,0))
#     plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
#     directory_out=out_path+'mollweide/'+'100_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
#     if not os.path.exists(directory_out):
#         os.makedirs(directory_out)
#     max_density=np.loadtxt(files_list[i], delimiter=' ');
#     hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang,norm='log',rot=(0,90,0))
#     plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
#     directory_out=out_path+'mollweide/'+'100_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
#     if not os.path.exists(directory_out):
#         os.makedirs(directory_out)
#     max_density=np.loadtxt(files_list[i], delimiter=' ');
#     hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang2,norm='log',rot=(0,90,0))
#     plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    
    
    directory_out=out_path+'mollweide/'+'111_'+'lin_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'111_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'111_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'mollweide/'+'111_'+'hist_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='hist',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'111_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,norm='hist',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'mollweide/'+'111_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,norm='hist',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
#     directory_out=out_path+'mollweide/'+'111_'+'log_'+'minmaxrang/'
#     if not os.path.exists(directory_out):
#         os.makedirs(directory_out)
#     max_density=np.loadtxt(files_list[i], delimiter=' ');
#     hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='log',rot=(0,45,45))
#     plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
#     directory_out=out_path+'mollweide/'+'111_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
#     if not os.path.exists(directory_out):
#         os.makedirs(directory_out)
#     max_density=np.loadtxt(files_list[i], delimiter=' ');
#     hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang,norm='log',rot=(0,45,45))
#     plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
#     directory_out=out_path+'mollweide/'+'111_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
#     if not os.path.exists(directory_out):
#         os.makedirs(directory_out)
#     max_density=np.loadtxt(files_list[i], delimiter=' ');
#     hp.mollview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang2,norm='log',rot=(0,45,45))
#     plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')

# %%
for i in range(0,len(files_list)):
    redshift = re.split("_",re.split("/", files_list[i])[-1])[-2][1:]
    print redshift
    
    directory_out=out_path+'cartview/'+'001_'+'lin_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'001_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang)
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'001_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2)
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'cartview/'+'001_'+'hist_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='hist')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'001_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,norm='hist')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'001_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,norm='hist')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'cartview/'+'001_'+'log_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='log')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'001_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang,norm='log')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'001_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang2,norm='log')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    
    directory_out=out_path+'cartview/'+'010_'+'lin_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'010_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'010_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'cartview/'+'010_'+'hist_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='hist',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'010_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,norm='hist',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'010_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,norm='hist',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'cartview/'+'010_'+'log_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='log',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'010_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang,norm='log',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'010_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang2,norm='log',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    
    directory_out=out_path+'cartview/'+'100_'+'lin_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'100_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'100_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'cartview/'+'100_'+'hist_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='hist',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'100_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,norm='hist',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'100_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,norm='hist',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'cartview/'+'100_'+'log_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='log',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'100_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang,norm='log',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'100_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang2,norm='log',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    
    
    directory_out=out_path+'cartview/'+'111_'+'lin_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'111_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'111_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'cartview/'+'111_'+'hist_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='hist',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'111_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,norm='hist',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'111_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,norm='hist',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'cartview/'+'111_'+'log_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='log',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'111_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang,norm='log',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'cartview/'+'111_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.cartview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang2,norm='log',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')

# %%
for i in range(0,len(files_list)):
    redshift = re.split("_",re.split("/", files_list[i])[-1])[-2][1:]
    print redshift
    
    directory_out=out_path+'orthview/'+'001_'+'lin_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'001_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang)
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'001_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2)
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'orthview/'+'001_'+'hist_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='hist')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'001_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,norm='hist')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'001_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,norm='hist')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'orthview/'+'001_'+'log_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='log')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'001_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang,norm='log')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'001_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang2,norm='log')
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    
    directory_out=out_path+'orthview/'+'010_'+'lin_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'010_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'010_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'orthview/'+'010_'+'hist_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='hist',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'010_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,norm='hist',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'010_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,norm='hist',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'orthview/'+'010_'+'log_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='log',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'010_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang,norm='log',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'010_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang2,norm='log',rot=(0,0,90))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    
    directory_out=out_path+'orthview/'+'100_'+'lin_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'100_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'100_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'orthview/'+'100_'+'hist_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='hist',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'100_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,norm='hist',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'100_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,norm='hist',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'orthview/'+'100_'+'log_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='log',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'100_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang,norm='log',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'100_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang2,norm='log',rot=(0,90,0))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    
    
    directory_out=out_path+'orthview/'+'111_'+'lin_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'111_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'111_'+'lin_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'orthview/'+'111_'+'hist_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='hist',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'111_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang,norm='hist',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'111_'+'hist_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=min_rang,max=max_rang2,norm='hist',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    
    directory_out=out_path+'orthview/'+'111_'+'log_'+'minmaxrang/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',norm='log',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'111_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang,norm='log',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')
    
    directory_out=out_path+'orthview/'+'111_'+'log_'+'fixrang_m'+str(min_rang)+'M'+str(max_rang2)+'/'
    if not os.path.exists(directory_out):
        os.makedirs(directory_out)
    max_density=np.loadtxt(files_list[i], delimiter=' ');
    hp.orthview(max_density,title='1dproj_'+comp+'_z'+redshift,unit='peak of the density contrast',min=0.001,max=max_rang2,norm='log',rot=(0,45,45))
    plt.savefig(directory_out+'1dproj_'+comp+'_z'+redshift+'.jpg')

# %%
files_list
# Out:
# []

# %%
max_density=np.loadtxt(files_list[3], delimiter=' ');
hp.mollview(max_density,title='1dproj_max_z'+redshift,unit='peak of the density contrast',nest='true')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-2ccaecbf25ac> in <module>()
# ----> 1 max_density=np.loadtxt(files_list[3], delimiter=' ');
#       2 hp.mollview(max_density,title='1dproj_max_z'+redshift,unit='peak of the density contrast',nest='true')
#
# IndexError: list index out of range
