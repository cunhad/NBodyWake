# %%
matplotlib inline

# %%
import numpy as np
import healpy as hp
from pylab import *
import matplotlib.pyplot as plt
import re
import glob
import os

# %%
#data

data_location="/home/asus/Dropbox/extras/storage/guillimin/box_stat/64Mpc_1024c_512p_zi63_wakeGmu1t10m7zi31m/sample0001/data/2lf_1rf_0-0-0pv/stat/box_statistics/dm/box_1dproj/_3_stn_1dproj_angle_z10_parts16_NSIDE64.bin"

values = np.fromfile(data_location, dtype=np.float32) 
angles=np.loadtxt('angles64.txt', delimiter=' ');

# %%
hp.mollview(values,title='1dproj',unit='peak of the density contrast')

# %%
hp.zoomtool.mollzoom(values, title="Mollview image RING")
