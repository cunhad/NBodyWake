# %%
matplotlib inline
# Out:
# /home/acer/miniconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import numpy as np
import healpy as hp

# %%
angles=np.loadtxt('angles64.txt', delimiter=' ');
#angles

# %%
NPix=angles.shape[1]
NSIDE = np.int(np.sqrt(NPix/12))

# %%
NSIDE,NPix
# Out:
# (64, 49152)

# %%
#uniform particle distribution

data_path_n="/home/acer/Documents/storage/irulan/test/uniform/50Mpc_128c_zi65_nowakes/Analysis/stat/box_statistics/healpy/*64_c.txt"

# %%
#uniform particle distribution with pole

data_path_n="/home/acer/Documents/storage/irulan/test/uniform/50Mpc_128c_zi65_nowakes/Analysis/stat/box_statistics/healpy/*8_pole.txt"

# %%
#from laptop
data_path="/home/acer/Documents/storage/40Mpc_192c_zi65_wakeGmu1t10m5zi40s/Analysis/stat/box_statistics/healpy/*8_pole.txt"
data_path_n="/home/acer/Documents/storage/40Mpc_192c_zi65_nowakes/Analysis/stat/box_statistics/healpy/*8_pole.txt"

# %%
#from laptop wake centered
data_path="/home/acer/Documents/storage/40Mpc_192c_zi65_wakeGmu1t10m5zi40s/Analysis/stat/box_statistics/healpy/*64_c.txt"
data_path_n="/home/acer/Documents/storage/40Mpc_192c_zi65_nowakes/Analysis/stat/box_statistics/healpy/*64_c.txt"

# %%
#from irulan 32Mpc_512c_zi63
data_path="/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_wakeGmu1t10m6zi15s/Analysis/stat/box_statistics/healpy/*64_c.txt"
data_path2="/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_wakeGmu1t10m6zi7s/Analysis/stat/box_statistics/healpy/*64_c.txt"
data_path_n="/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_nowakes/Analysis/stat/box_statistics/healpy/*64_c.txt"

# %%
#from irulan 50Mpc_512c_zi65 interesting

data_path="/home/acer/Documents/storage/irulan/interesting/50Mpc_512c_zi65_wakeGmu6t10m6zi40s/Analysis/stat/box_statistics/healpy/*8.txt"
data_path_n="/home/acer/Documents/storage/irulan/interesting/50Mpc_512c_zi65_nowakes/Analysis/stat/box_statistics/healpy/*8.txt"

# %%
#from irulan 16Mpc_512c_zi63

data_path="/home/acer/Documents/storage/irulan/16Mpc_512c_zi63_wakeGmu1t10m6zi15s/Analysis/stat/box_statistics/healpy/*64_c.txt"
data_path_n="/home/acer/Documents/storage/irulan/16Mpc_512c_zi63_nowakes/Analysis/stat/box_statistics/healpy/*64_c.txt"

# %%
import glob
files_list_n = sorted(glob.glob(data_path_n))
files_list_n
# Out:
# ['/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_nowakes/Analysis/stat/box_statistics/healpy/_4max_1ddensity_z2_healpy64_c.txt',
#  '/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_nowakes/Analysis/stat/box_statistics/healpy/_5max_1ddensity_z3_healpy64_c.txt',
#  '/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_nowakes/Analysis/stat/box_statistics/healpy/_6max_1ddensity_z4_healpy64_c.txt',
#  '/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_nowakes/Analysis/stat/box_statistics/healpy/_7max_1ddensity_z5_healpy64_c.txt',
#  '/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_nowakes/Analysis/stat/box_statistics/healpy/_8max_1ddensity_z6_healpy64_c.txt']

# %%
max_density=np.loadtxt(files_list_n[4], delimiter=' ');
#max_density
hp.mollview(max_density,title='32Mpc_512c_zi63_nowakes_z6')

# %%
import glob
files_list = sorted(glob.glob(data_path))
files_list
# Out:
# ['/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_wakeGmu1t10m6zi15s/Analysis/stat/box_statistics/healpy/_4max_1ddensity_z2_healpy64_c.txt',
#  '/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_wakeGmu1t10m6zi15s/Analysis/stat/box_statistics/healpy/_5max_1ddensity_z3_healpy64_c.txt',
#  '/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_wakeGmu1t10m6zi15s/Analysis/stat/box_statistics/healpy/_6max_1ddensity_z4_healpy64_c.txt',
#  '/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_wakeGmu1t10m6zi15s/Analysis/stat/box_statistics/healpy/_7max_1ddensity_z5_healpy64_c.txt',
#  '/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_wakeGmu1t10m6zi15s/Analysis/stat/box_statistics/healpy/_8max_1ddensity_z6_healpy64_c.txt']

# %%
max_density=np.loadtxt(files_list[4], delimiter=' ');
#max_density.0p
hp.mollview(max_density,title='32Mpc_512c_zi63_wakeGmu1t10m6zi15s_z6')

# %%
import glob
files_list2 = sorted(glob.glob(data_path2))
files_list2
# Out:
# ['/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_wakeGmu1t10m6zi7s/Analysis/stat/box_statistics/healpy/_4max_1ddensity_z2_healpy64_c.txt',
#  '/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_wakeGmu1t10m6zi7s/Analysis/stat/box_statistics/healpy/_5max_1ddensity_z3_healpy64_c.txt',
#  '/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_wakeGmu1t10m6zi7s/Analysis/stat/box_statistics/healpy/_6max_1ddensity_z4_healpy64_c.txt',
#  '/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_wakeGmu1t10m6zi7s/Analysis/stat/box_statistics/healpy/_7max_1ddensity_z5_healpy64_c.txt',
#  '/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_wakeGmu1t10m6zi7s/Analysis/stat/box_statistics/healpy/_8max_1ddensity_z6_healpy64_c.txt']

# %%
max_density=np.loadtxt(files_list2[4], delimiter=' ');
#max_density.0p
hp.mollview(max_density,title='32Mpc_512c_zi63_wakeGmu1t10m6zi7s_z6')
