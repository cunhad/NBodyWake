# %%
matplotlib inline
# Out:
# /home/acer/miniconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import numpy as np
import healpy as hp

# %%
angles=np.loadtxt('angles64.txt', delimiter=' ');
#angles

# %%
NPix=angles.shape[1]
NSIDE = np.int(np.sqrt(NPix/12))

# %%
NSIDE,NPix
# Out:
# (64, 49152)

# %%
#uniform particle distribution

data_path_n="/home/acer/Documents/storage/irulan/test/uniform/50Mpc_128c_zi65_nowakes/Analysis/stat/box_statistics/healpy/*8.txt"

# %%
#from laptop
data_path="/home/acer/Documents/storage/40Mpc_192c_zi65_wakeGmu1t10m5zi40s/Analysis/stat/box_statistics/healpy/*64.txt"
data_path_n="/home/acer/Documents/storage/40Mpc_192c_zi65_nowakes/Analysis/stat/box_statistics/healpy/*64.txt"

# %%
#from irulan
#data_path="/home/acer/Documents/storage/irulan/50Mpc_512c_zi65_wakeGmu6t10m6zi40s/Analysis/stat/box_statistics/healpy/*8.txt"
#data_path_n="/home/acer/Documents/storage/irulan/50Mpc_512c_zi65_nowakes/Analysis/stat/box_statistics/healpy/*8.txt"

# %%
import glob
files_list = glob.glob(data_path)
files_list
# Out:
# ['/home/acer/Documents/storage/40Mpc_192c_zi65_wakeGmu1t10m5zi40s/Analysis/stat/box_statistics/healpy/max_1ddensity_z0_healpy64.txt']

# %%
max_density=np.loadtxt(files_list[0], delimiter=' ');
#max_density
hp.mollview(max_density, title="Mollview image RING")

# %%
import glob
files_list_n = glob.glob(data_path_n)
files_list_n
# Out:
# ['/home/acer/Documents/storage/irulan/test/uniform/50Mpc_128c_zi65_nowakes/Analysis/stat/box_statistics/healpy/max_1ddensity_z0.5_healpy8.txt',
#  '/home/acer/Documents/storage/irulan/test/uniform/50Mpc_128c_zi65_nowakes/Analysis/stat/box_statistics/healpy/max_1ddensity_z0_healpy8.txt']

# %%
max_density=np.loadtxt(files_list_n[1], delimiter=' ');
#max_density
hp.mollview(max_density, title="Mollview image RING")
