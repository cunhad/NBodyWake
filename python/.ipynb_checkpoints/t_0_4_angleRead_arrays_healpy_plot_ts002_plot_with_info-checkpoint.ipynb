# %%
matplotlib inline

# %%
import numpy as np
import healpy as hp
from pylab import *
import matplotlib.pyplot as plt

# %%
#from guillimim 8 nodes simplest one 32Mpc_96c_zi63_nowakes

data_path="/home/asus/Dropbox/extras/storage/guillimin/old/32Mpc_96c_zi63_nowakes/Analysis/stat/box_statistics/max_1dproj/*64.txt"

# %%
#out path

out_path="/home/asus/Dropbox/extras/storage/guillimin/old/32Mpc_96c_zi63_nowakes/Analysis/stat/box_statistics/max_1dproj/"

# %%
angles=np.loadtxt('angles64.txt', delimiter=' ');
#angles

# %%
NPix=angles.shape[1]
NSIDE = np.int(np.sqrt(NPix/12))

# %%
NSIDE,NPix
# Out:
# (64, 49152)

# %%
import glob
files_list = sorted(glob.glob(data_path))
files_list
# Out:
# ['/home/asus/Dropbox/extras/storage/guillimin/old/32Mpc_96c_zi63_nowakes/Analysis/stat/box_statistics/max_1dproj/1dproj_max_z31_NSIDE64.txt',
#  '/home/asus/Dropbox/extras/storage/guillimin/old/32Mpc_96c_zi63_nowakes/Analysis/stat/box_statistics/max_1dproj/1dproj_max_z63_NSIDE64.txt']

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
#max_density.0p
#hp.mollview(max_density,title='50Mpc_502c_zi65_wakeGmu6t10m6zi40s_z2')
plot = hp.mollview(max_density)

# %%
hp.mollview(max_density)
plt.savefig(out_path+'test2.jpg')

# %%
import re
str2=re.split("/", files_list[1])
print str2
# Out:
# ['', 'home', 'asus', 'Dropbox', 'extras', 'storage', 'guillimin', 'old', '32Mpc_96c_zi63_nowakes', 'Analysis', 'stat', 'box_statistics', 'max_1dproj', '1dproj_max_z63_NSIDE64.txt']

# %%
str2
str2[-1]
# Out:
# '1dproj_max_z63_NSIDE64.txt'

# %%
re.split("/", files_list[1])[-1]
# Out:
# '1dproj_max_z63_NSIDE64.txt'

# %% [raw]
# re.split("_",re.split("/", files_list[1])[-1])

# %%
re.split("_",re.split("/", files_list[1])[-1])
# Out:
# ['1dproj', 'max', 'z63', 'NSIDE64.txt']

# %%
redshift = re.split("/", files_list[1])[-1][12:14]

# %%
redshift
# Out:
# '63'

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.mollview(max_density,title='1dproj_max_z63_NSIDE64',unit='mK', min=0,max=1)
plt.savefig(out_path+'test2.jpg')

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.mollview(max_density,title='1dproj_max_z63_NSIDE64',unit='mK', min=0,max=1,norm='hist')
plt.savefig(out_path+'test2.jpg')

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.mollview(max_density,title='1dproj_max_z63_NSIDE64',unit='mK', min=0.1,max=1,norm='log')
plt.savefig(out_path+'test2.jpg')

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.mollview(max_density,title='1dproj_max_z63_NSIDE64',unit='mK',nest=True, min=0.1,max=1,norm='log')
plt.savefig(out_path+'test2.jpg')

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.mollview(max_density,title='1dproj_max_z63_NSIDE64',unit='mK',nest=True, min=0.1,max=1)
plt.savefig(out_path+'test2.jpg')

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.cartview(max_density,title='1dproj_max_z63_NSIDE64',unit='mK',nest=True, min=0.1,max=1)
plt.savefig(out_path+'test2.jpg')

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.cartview(max_density,title='1dproj_max_z63_NSIDE64',unit='mK', min=0.1,max=1)
plt.savefig(out_path+'test2.jpg')

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.gnomview(max_density,title='1dproj_max_z63_NSIDE64',unit='mK', min=0.1,max=1)
plt.savefig(out_path+'test2.jpg')

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.orthview(max_density,title='1dproj_max_z63_NSIDE64',unit='mK', min=0.1,max=1)
plt.savefig(out_path+'test2.jpg')
# Out:
# /home/asus/Programs/anaconda/Programs/anaconda/lib/python2.7/site-packages/numpy/core/numeric.py:190: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   a = empty(shape, dtype, order)

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.orthview(max_density,title='1dproj_max_z63_NSIDE64',unit='mK', min=0.1,max=1,rot = ( 45, 45, 45)  )
plt.savefig(out_path+'test2.jpg')

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.mollview(max_density,title='1dproj_max_z63_NSIDE64',unit='mK',nest=True)
plt.savefig(out_path+'test2.jpg')

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.mollview(max_density,title='1dproj_max_z63_NSIDE64',unit='mK',nest=True,norm="hist")
plt.savefig(out_path+'test2.jpg')

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.mollview(max_density,title='1dproj_max_z63_NSIDE64',unit='mK',nest=True,norm="hist",min=0,max=1)
plt.savefig(out_path+'test2.jpg')

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.mollview(max_density,title='1dproj_max_z63_NSIDE64',unit='mK',norm="hist",min=0,max=1)
plt.savefig(out_path+'test2.jpg')

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.gnomview(max_density,title='1dproj_max_z63_NSIDE64',unit='mK',norm="hist",min=0,max=1)
plt.savefig(out_path+'test2.jpg')

# %%
max_density=np.loadtxt(files_list[1], delimiter=' ');
hp.mollzoom(max_density,title='1dproj_max_z63_NSIDE64',unit='mK',norm="hist",min=0,max=1)
plt.savefig(out_path+'test2.jpg')
