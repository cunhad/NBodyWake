# %%
matplotlib inline

# %%
import numpy as np
import healpy as hp

# %%
angles=np.loadtxt('angles64.txt', delimiter=' ');
#angles

# %%
NPix=angles.shape[1]
NSIDE = np.int(np.sqrt(NPix/12))

# %%
NSIDE,NPix
# Out:
# (64, 49152)

# %%
max_density=np.loadtxt('random_test64.txt', delimiter=' ');
#max_density

# %%
hp.mollview(max_density, title="Mollview image RING")
