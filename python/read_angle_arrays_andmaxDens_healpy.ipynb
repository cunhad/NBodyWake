# %%
matplotlib inline

# %%
import numpy as np
import healpy as hp

# %%
angles=np.loadtxt('angles64.txt', delimiter=' ');
#angles

# %%
NPix=angles.shape[1]
NSIDE = np.int(np.sqrt(NPix/12))

# %%
NSIDE,NPix
# Out:
# (64, 49152)

# %%
#uniform particle distribution

data_path_n="/home/acer/Documents/storage/irulan/test/uniform/50Mpc_128c_zi65_nowakes/Analysis/stat/box_statistics/healpy/*64_c.txt"

# %%
#uniform particle distribution with pole

data_path_n="/home/acer/Documents/storage/irulan/test/uniform/50Mpc_128c_zi65_nowakes/Analysis/stat/box_statistics/healpy/*8_pole.txt"

# %%
#from laptop
data_path="/home/acer/Documents/storage/40Mpc_192c_zi65_wakeGmu1t10m5zi40s/Analysis/stat/box_statistics/healpy/*8_pole.txt"
data_path_n="/home/acer/Documents/storage/40Mpc_192c_zi65_nowakes/Analysis/stat/box_statistics/healpy/*8_pole.txt"

# %%
#from laptop wake centered
data_path="/home/acer/Documents/storage/40Mpc_192c_zi65_wakeGmu1t10m5zi40s/Analysis/stat/box_statistics/healpy/*64_c.txt"
data_path_n="/home/acer/Documents/storage/40Mpc_192c_zi65_nowakes/Analysis/stat/box_statistics/healpy/*64_c.txt"

# %%
#from irulan 32Mpc_512c_zi63
data_path="/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_wakeGmu1t10m6zi15s/Analysis/stat/box_statistics/healpy/*64_c.txt"
data_path_n="/home/acer/Documents/storage/irulan/32Mpc_512c_zi63_nowakes/Analysis/stat/box_statistics/healpy/*64_c.txt"

# %%
import glob
files_list = sorted(glob.glob(data_path))
files_list
# Out:
# ['/home/acer/Documents/storage/40Mpc_192c_zi65_wakeGmu1t10m5zi40s/Analysis/stat/box_statistics/healpy/_1max_1ddensity_z0_healpy64_c.txt',
#  '/home/acer/Documents/storage/40Mpc_192c_zi65_wakeGmu1t10m5zi40s/Analysis/stat/box_statistics/healpy/_2max_1ddensity_z0.5_healpy64_c.txt',
#  '/home/acer/Documents/storage/40Mpc_192c_zi65_wakeGmu1t10m5zi40s/Analysis/stat/box_statistics/healpy/_3max_1ddensity_z1_healpy64_c.txt',
#  '/home/acer/Documents/storage/40Mpc_192c_zi65_wakeGmu1t10m5zi40s/Analysis/stat/box_statistics/healpy/_4max_1ddensity_z2_healpy64_c.txt',
#  '/home/acer/Documents/storage/40Mpc_192c_zi65_wakeGmu1t10m5zi40s/Analysis/stat/box_statistics/healpy/_5max_1ddensity_z3_healpy64_c.txt']

# %%
max_density=np.loadtxt(files_list[0], delimiter=' ');
#max_density
hp.mollview(max_density, title="Mollview image RING")

# %%
import glob
files_list_n = sorted(glob.glob(data_path_n))
files_list_n
# Out:
# ['/home/acer/Documents/storage/40Mpc_192c_zi65_nowakes/Analysis/stat/box_statistics/healpy/_1max_1ddensity_z0_healpy64_c.txt',
#  '/home/acer/Documents/storage/40Mpc_192c_zi65_nowakes/Analysis/stat/box_statistics/healpy/_2max_1ddensity_z0.5_healpy64_c.txt',
#  '/home/acer/Documents/storage/40Mpc_192c_zi65_nowakes/Analysis/stat/box_statistics/healpy/_3max_1ddensity_z1_healpy64_c.txt',
#  '/home/acer/Documents/storage/40Mpc_192c_zi65_nowakes/Analysis/stat/box_statistics/healpy/_4max_1ddensity_z2_healpy64_c.txt',
#  '/home/acer/Documents/storage/40Mpc_192c_zi65_nowakes/Analysis/stat/box_statistics/healpy/_5max_1ddensity_z3_healpy64_c.txt']

# %%
max_density=np.loadtxt(files_list_n[0], delimiter=' ');
#max_density.0p
hp.mollview(max_density, title="Mollview image RING")
